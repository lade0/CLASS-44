# %% [markdown]
# <a href="https://colab.research.google.com/github/lade0/CLASS-44/blob/main/class_45_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from google.colab import files
Files=files.upload()
# Out:
#      <input type="file" id="files-491f5873-6314-4fcc-9c70-886b5280fbd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-491f5873-6314-4fcc-9c70-886b5280fbd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
iris=pd.read_csv('Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.barplot(x=iris['Species'],y=iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.countplot(iris['Species'])
# Out:
# <Axes: xlabel='count', ylabel='Species'>

# %%
sns.boxplot(x=iris['Species'],y=iris['SepalWidthCm'])
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.swarmplot(x=iris['Species'],y=iris['SepalWidthCm'],hue=iris['Species'])
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.distplot(iris['SepalWidthCm'])
# Out:
# <ipython-input-12-2081958343>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['SepalWidthCm'])
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.distplot(iris['SepalWidthCm'],rug=True)
# Out:
# <ipython-input-14-2219401273>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['SepalWidthCm'],rug=True)
# <Axes: xlabel='SepalWidthCm', ylabel='Density'>

# %%
sns.jointplot(iris['SepalWidthCm'])

# %%
sns.jointplot(iris['SepalWidthCm'],kind='kde')

# %%
sns.jointplot(iris['SepalWidthCm'], kind='hex')

# %%
sns.pairplot(iris[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])
